# %%
import pandas as pd
from rdkit.Chem import PandasTools

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
df = pd.read_csv('data/test.csv')
PandasTools.AddMoleculeColumnToFrame(df, 'smiles')
df
# Out:
#        id    smiles                                             ROMol
# 0  vai_01       CCC  <rdkit.Chem.rdchem.Mol object at 0x7f98b0affb80>
# 1  vai_02  C1CCCCC1  <rdkit.Chem.rdchem.Mol object at 0x7f98b0affbe0>
